# %% [markdown]
# ## Environment Setup

# %%
# !pip install -q gdown numpy pandas scikit-learn pillow opencv-python

# %%
# !pip install -q torch torchvision protobuf sentencepiece transformers datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 37.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.

# %%
# hyper-parameter
epochs = 10
batch_size = 32
lr = 1e-04
seed = 42
early_stop = False
patience = 5
aug_data = 1.0

# %%
import random
import numpy as np
import torch

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(seed=42)

# %% [markdown]
# ## Download the Dataset

# %%
# !gdown 1amslR99ZakBHnfBkeSeTazO6XhzOTYsc
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1amslR99ZakBHnfBkeSeTazO6XhzOTYsc
# From (redirected): https://drive.google.com/uc?id=1amslR99ZakBHnfBkeSeTazO6XhzOTYsc&confirm=t&uuid=9ea7924c-78e6-42f1-b5c7-8312350291a6
# To: /content/data_a.zip
# 100% 339M/339M [00:15<00:00, 22.0MB/s]

# %%
# !unzip data_a.zip -d ./
# Out:
# Archive:  data_a.zip
#    creating: ./data/
#    creating: ./data/test_images/
#   inflating: ./__MACOSX/data/._test_images
#   inflating: ./data/train_doc_info.pkl
#    creating: ./data/printed_images/
#   inflating: ./__MACOSX/data/._printed_images
#   inflating: ./data/.DS_Store
#   inflating: ./__MACOSX/data/._.DS_Store
#    creating: ./data/val_images/
#   inflating: ./__MACOSX/data/._val_images
#   inflating: ./data/val_doc_info.pkl
#   inflating: ./data/submission.csv
#   inflating: ./__MACOSX/data/._submission.csv
#   inflating: ./data/test_doc_info.pkl
#   inflating: ./data/train_dataframe.csv
#   inflating: ./__MACOSX/data/._train_dataframe.csv
#   inflating: ./data/val_dataframe.csv
#   inflating: ./__MACOSX/data/._val_dataframe.csv
#    creating: ./data/train_images/
#   inflating: ./__MACOSX/data/._train_images
#   inflating: ./data/test_printed_dataframe.csv
#   inflating: ./__MACOSX/data/._test_printed_dataframe.csv
#   inflating: ./data/printed_doc_info.pkl
#   inflating: ./data/test_images/00925233_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925233_page-0.png
#   inflating: ./data/test_images/00936410_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00936410_page-0.png
#   inflating: ./data/test_images/00918204_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00918204_page-0.png
#   inflating: ./data/test_images/00937785_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00937785_page-0.png
#   inflating: ./data/test_images/00934502_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934502_page-0.png
#   inflating: ./data/test_images/00934748_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934748_page-0.png
#   inflating: ./data/test_images/00933799_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00933799_page-0.png
#   inflating: ./data/test_images/00923421_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00923421_page-0.png
#   inflating: ./data/test_images/00922440_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922440_page-0.png
#   inflating: ./data/test_images/00927177_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927177_page-0.png
#   inflating: ./data/test_images/00923814_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00923814_page-1.png
#   inflating: ./data/test_images/00929775_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929775_page-0.png
#   inflating: ./data/test_images/00924710_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924710_page-0.png
#   inflating: ./data/test_images/00921817_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00921817_page-0.png
#   inflating: ./data/test_images/00926953_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00926953_page-1.png
#   inflating: ./data/test_images/00936399_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00936399_page-0.png
#   inflating: ./data/test_images/00929793_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929793_page-0.png
#   inflating: ./data/test_images/00924118_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924118_page-0.png
#   inflating: ./data/test_images/00918399_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00918399_page-1.png
#   inflating: ./data/test_images/00927516_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927516_page-0.png
#   inflating: ./data/test_images/00923338_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00923338_page-0.png
#   inflating: ./data/test_images/00924832_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924832_page-0.png
#   inflating: ./data/test_images/00928469_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00928469_page-0.png
#   inflating: ./data/test_images/00929142_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929142_page-0.png
#   inflating: ./data/test_images/00919416_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919416_page-0.png
#   inflating: ./data/test_images/00927610_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927610_page-0.png
#   inflating: ./data/test_images/00924819_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924819_page-0.png
#   inflating: ./data/test_images/00920257_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920257_page-0.png
#   inflating: ./data/test_images/00922942_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922942_page-0.png
#   inflating: ./data/test_images/00927581_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927581_page-0.png
#   inflating: ./data/test_images/00921325_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00921325_page-0.png
#   inflating: ./data/test_images/00919764_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00919764_page-1.png
#   inflating: ./data/test_images/00930886_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00930886_page-0.png
#   inflating: ./data/test_images/00917958_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00917958_page-0.png
#   inflating: ./data/test_images/00935689_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00935689_page-0.png
#   inflating: ./data/test_images/00921644_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00921644_page-0.png
#   inflating: ./data/test_images/00926108_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926108_page-0.png
#   inflating: ./data/test_images/00933796_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00933796_page-0.png
#   inflating: ./data/test_images/00922822_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00922822_page-1.png
#   inflating: ./data/test_images/00918569_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00918569_page-0.png
#   inflating: ./data/test_images/00930070_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00930070_page-1.png
#   inflating: ./data/test_images/00932303_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00932303_page-0.png
#   inflating: ./data/test_images/00919628_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919628_page-0.png
#   inflating: ./data/test_images/00924437_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00924437_page-1.png
#   inflating: ./data/test_images/00920161_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00920161_page-1.png
#   inflating: ./data/test_images/00842499_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00842499_page-0.png
#   inflating: ./data/test_images/00929302_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929302_page-0.png
#   inflating: ./data/test_images/00921356_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00921356_page-0.png
#   inflating: ./data/test_images/00928436_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00928436_page-0.png
#   inflating: ./data/test_images/00926487_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926487_page-0.png
#   inflating: ./data/test_images/00934498_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934498_page-0.png
#   inflating: ./data/test_images/00934838_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934838_page-0.png
#   inflating: ./data/test_images/00930241_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00930241_page-0.png
#   inflating: ./data/test_images/00918815_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00918815_page-0.png
#   inflating: ./data/test_images/00919226_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919226_page-0.png
#   inflating: ./data/test_images/00935334_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00935334_page-0.png
#   inflating: ./data/test_images/00840748_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00840748_page-0.png
#   inflating: ./data/test_images/00929343_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929343_page-0.png
#   inflating: ./data/test_images/00924734_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924734_page-0.png
#   inflating: ./data/test_images/00846052_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00846052_page-0.png
#   inflating: ./data/test_images/00842551_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00842551_page-0.png
#   inflating: ./data/test_images/00925055_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925055_page-0.png
#   inflating: ./data/test_images/00919389_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919389_page-0.png
#   inflating: ./data/test_images/00929235_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00929235_page-1.png
#   inflating: ./data/test_images/00919003_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919003_page-0.png
#   inflating: ./data/test_images/00844109_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00844109_page-0.png
#   inflating: ./data/test_images/00845315_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00845315_page-0.png
#   inflating: ./data/test_images/00922493_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922493_page-0.png
#   inflating: ./data/test_images/00924464_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00924464_page-1.png
#   inflating: ./data/test_images/00844107_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00844107_page-0.png
#   inflating: ./data/test_images/00918606_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00918606_page-1.png
#   inflating: ./data/test_images/00925606_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925606_page-0.png
#   inflating: ./data/test_images/00921590_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00921590_page-1.png
#   inflating: ./data/test_images/00926437_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926437_page-0.png
#   inflating: ./data/test_images/00925935_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925935_page-0.png
#   inflating: ./data/test_images/00921290_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00921290_page-0.png
#   inflating: ./data/test_images/00921273_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00921273_page-1.png
#   inflating: ./data/test_images/00918178_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00918178_page-1.png
#   inflating: ./data/test_images/00935595_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00935595_page-0.png
#   inflating: ./data/test_images/00936992_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00936992_page-0.png
#   inflating: ./data/test_images/00925495_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00925495_page-1.png
#   inflating: ./data/test_images/00919689_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919689_page-0.png
#   inflating: ./data/test_images/00929143_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929143_page-0.png
#   inflating: ./data/test_images/00925696_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925696_page-0.png
#   inflating: ./data/test_images/00922064_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922064_page-0.png
#   inflating: ./data/test_images/00926139_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926139_page-0.png
#   inflating: ./data/test_images/00842346_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00842346_page-0.png
#   inflating: ./data/test_images/00922943_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922943_page-0.png
#   inflating: ./data/test_images/00928502_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00928502_page-0.png
#   inflating: ./data/test_images/00934176_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934176_page-0.png
#   inflating: ./data/test_images/00925426_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925426_page-0.png
#   inflating: ./data/test_images/00843409_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00843409_page-0.png
#   inflating: ./data/test_images/00929146_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929146_page-0.png
#   inflating: ./data/test_images/00926913_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926913_page-0.png
#   inflating: ./data/test_images/00918232_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00918232_page-0.png
#   inflating: ./data/test_images/00934503_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934503_page-0.png
#   inflating: ./data/test_images/00933798_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00933798_page-0.png
#   inflating: ./data/test_images/00926782_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00926782_page-1.png
#   inflating: ./data/test_images/00936344_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00936344_page-0.png
#   inflating: ./data/test_images/00920425_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920425_page-0.png
#   inflating: ./data/test_images/00840861_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00840861_page-0.png
#   inflating: ./data/test_images/00925053_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925053_page-0.png
#   inflating: ./data/test_images/00924767_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924767_page-0.png
#   inflating: ./data/test_images/00920951_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920951_page-0.png
#   inflating: ./data/test_images/00844774_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00844774_page-0.png
#   inflating: ./data/test_images/00844209_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00844209_page-0.png
#   inflating: ./data/test_images/00842710_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00842710_page-0.png
#   inflating: ./data/test_images/00926770_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00926770_page-1.png
#   inflating: ./data/test_images/00933999_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00933999_page-0.png
#   inflating: ./data/test_images/00920382_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920382_page-0.png
#   inflating: ./data/test_images/00927212_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927212_page-0.png
#   inflating: ./data/test_images/00918813_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00918813_page-1.png
#   inflating: ./data/test_images/00920928_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920928_page-0.png
#   inflating: ./data/test_images/00925059_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925059_page-0.png
#   inflating: ./data/test_images/00920713_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00920713_page-0.png
#   inflating: ./data/test_images/00926826_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926826_page-0.png
#   inflating: ./data/test_images/00925365_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925365_page-0.png
#   inflating: ./data/test_images/00925386_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925386_page-0.png
#   inflating: ./data/test_images/00926950_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00926950_page-1.png
#   inflating: ./data/test_images/00918213_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00918213_page-0.png
#   inflating: ./data/test_images/00842300_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00842300_page-0.png
#   inflating: ./data/test_images/00926597_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926597_page-0.png
#   inflating: ./data/test_images/00924621_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924621_page-0.png
#   inflating: ./data/test_images/00924674_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924674_page-0.png
#   inflating: ./data/test_images/00924757_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00924757_page-0.png
#   inflating: ./data/test_images/00919388_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919388_page-0.png
#   inflating: ./data/test_images/00933494_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00933494_page-0.png
#   inflating: ./data/test_images/00926033_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00926033_page-0.png
#   inflating: ./data/test_images/00934491_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934491_page-0.png
#   inflating: ./data/test_images/00925109_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00925109_page-0.png
#   inflating: ./data/test_images/00935586_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00935586_page-0.png
#   inflating: ./data/test_images/00844108_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00844108_page-0.png
#   inflating: ./data/test_images/00922343_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922343_page-0.png
#   inflating: ./data/test_images/00926048_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00926048_page-1.png
#   inflating: ./data/test_images/00919007_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919007_page-0.png
#   inflating: ./data/test_images/00919624_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919624_page-0.png
#   inflating: ./data/test_images/00928006_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00928006_page-0.png
#   inflating: ./data/test_images/00929776_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00929776_page-0.png
#   inflating: ./data/test_images/00927210_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00927210_page-0.png
#   inflating: ./data/test_images/00931452_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00931452_page-0.png
#   inflating: ./data/test_images/00934842_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00934842_page-0.png
#   inflating: ./data/test_images/00918601_page-1.png
#   inflating: ./__MACOSX/data/test_images/._00918601_page-1.png
#   inflating: ./data/test_images/00937436_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00937436_page-0.png
#   inflating: ./data/test_images/00919336_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00919336_page-0.png
#   inflating: ./data/test_images/00922546_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00922546_page-0.png
#   inflating: ./data/test_images/00928952_page-0.png
#   inflating: ./__MACOSX/data/test_images/._00928952_page-0.png
#   inflating: ./data/printed_images/00345379_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345379_page-0.png
#   inflating: ./data/printed_images/00344333_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344333_page-1.png
#   inflating: ./data/printed_images/00344210_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344210_page-1.png
#   inflating: ./data/printed_images/00345224_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345224_page-1.png
#   inflating: ./data/printed_images/00344536_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344536_page-1.png
#   inflating: ./data/printed_images/00344236_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344236_page-1.png
#   inflating: ./data/printed_images/00343757_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00343757_page-1.png
#   inflating: ./data/printed_images/00343925_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00343925_page-0.png
#   inflating: ./data/printed_images/00345371_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345371_page-0.png
#   inflating: ./data/printed_images/00344629_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344629_page-1.png
#   inflating: ./data/printed_images/00344964_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344964_page-1.png
#   inflating: ./data/printed_images/00344716_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00344716_page-0.png
#   inflating: ./data/printed_images/00345226_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345226_page-1.png
#   inflating: ./data/printed_images/00345367_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345367_page-0.png
#   inflating: ./data/printed_images/00343795_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00343795_page-1.png
#   inflating: ./data/printed_images/00343891_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00343891_page-0.png
#   inflating: ./data/printed_images/00344737_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344737_page-1.png
#   inflating: ./data/printed_images/00344503_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344503_page-1.png
#   inflating: ./data/printed_images/00345082_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345082_page-1.png
#   inflating: ./data/printed_images/00344649_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344649_page-1.png
#   inflating: ./data/printed_images/00344891_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344891_page-1.png
#   inflating: ./data/printed_images/00345042_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345042_page-1.png
#   inflating: ./data/printed_images/00345362_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345362_page-0.png
#   inflating: ./data/printed_images/00344006_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344006_page-1.png
#   inflating: ./data/printed_images/00345361_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345361_page-0.png
#   inflating: ./data/printed_images/00344349_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344349_page-1.png
#   inflating: ./data/printed_images/00344381_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00344381_page-0.png
#   inflating: ./data/printed_images/00345011_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345011_page-1.png
#   inflating: ./data/printed_images/00344290_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344290_page-1.png
#   inflating: ./data/printed_images/00344793_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344793_page-1.png
#   inflating: ./data/printed_images/00343916_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00343916_page-0.png
#   inflating: ./data/printed_images/00344004_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344004_page-1.png
#   inflating: ./data/printed_images/00344338_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344338_page-1.png
#   inflating: ./data/printed_images/00344346_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344346_page-1.png
#   inflating: ./data/printed_images/00345138_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345138_page-1.png
#   inflating: ./data/printed_images/00343763_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00343763_page-1.png
#   inflating: ./data/printed_images/00343926_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00343926_page-0.png
#   inflating: ./data/printed_images/00345380_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00345380_page-0.png
#   inflating: ./data/printed_images/00344216_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344216_page-1.png
#   inflating: ./data/printed_images/00344335_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344335_page-1.png
#   inflating: ./data/printed_images/00345401_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345401_page-1.png
#   inflating: ./data/printed_images/00343823_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00343823_page-1.png
#   inflating: ./data/printed_images/00344740_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344740_page-1.png
#   inflating: ./data/printed_images/00344618_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344618_page-1.png
#   inflating: ./data/printed_images/00344889_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344889_page-1.png
#   inflating: ./data/printed_images/00344604_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00344604_page-1.png
#   inflating: ./data/printed_images/00345071_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345071_page-1.png
#   inflating: ./data/printed_images/00344365_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00344365_page-0.png
#   inflating: ./data/printed_images/00343849_page-0.png
#   inflating: ./__MACOSX/data/printed_images/._00343849_page-0.png
#   inflating: ./data/printed_images/00345083_page-1.png
#   inflating: ./__MACOSX/data/printed_images/._00345083_page-1.png
#   inflating: ./data/val_images/00917669_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917669_page-0.png
#   inflating: ./data/val_images/00912114_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00912114_page-0.png
#   inflating: ./data/val_images/00914344_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914344_page-0.png
#   inflating: ./data/val_images/00916910_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00916910_page-1.png
#   inflating: ./data/val_images/00912623_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00912623_page-1.png
#   inflating: ./data/val_images/00913924_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913924_page-0.png
#   inflating: ./data/val_images/00917332_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00917332_page-1.png
#   inflating: ./data/val_images/00917653_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917653_page-0.png
#   inflating: ./data/val_images/00915918_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00915918_page-1.png
#   inflating: ./data/val_images/00913929_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913929_page-0.png
#   inflating: ./data/val_images/00911933_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911933_page-1.png
#   inflating: ./data/val_images/00914349_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914349_page-1.png
#   inflating: ./data/val_images/00917717_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917717_page-0.png
#   inflating: ./data/val_images/00913214_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913214_page-0.png
#   inflating: ./data/val_images/00838702_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00838702_page-0.png
#   inflating: ./data/val_images/00912985_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00912985_page-1.png
#   inflating: ./data/val_images/00914631_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914631_page-0.png
#   inflating: ./data/val_images/00839468_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00839468_page-1.png
#   inflating: ./data/val_images/00836339_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00836339_page-0.png
#   inflating: ./data/val_images/00917921_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917921_page-0.png
#   inflating: ./data/val_images/00911037_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911037_page-1.png
#   inflating: ./data/val_images/00838896_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00838896_page-0.png
#   inflating: ./data/val_images/00913235_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913235_page-0.png
#   inflating: ./data/val_images/00916422_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00916422_page-1.png
#   inflating: ./data/val_images/00913926_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913926_page-0.png
#   inflating: ./data/val_images/00914346_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914346_page-0.png
#   inflating: ./data/val_images/00911030_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00911030_page-0.png
#   inflating: ./data/val_images/00915277_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00915277_page-0.png
#   inflating: ./data/val_images/00911931_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911931_page-1.png
#   inflating: ./data/val_images/00839326_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00839326_page-0.png
#   inflating: ./data/val_images/00839284_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00839284_page-0.png
#   inflating: ./data/val_images/00836340_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00836340_page-0.png
#   inflating: ./data/val_images/00913268_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913268_page-0.png
#   inflating: ./data/val_images/00911399_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911399_page-1.png
#   inflating: ./data/val_images/00915418_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00915418_page-0.png
#   inflating: ./data/val_images/00911029_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00911029_page-0.png
#   inflating: ./data/val_images/00910694_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00910694_page-1.png
#   inflating: ./data/val_images/00914640_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914640_page-1.png
#   inflating: ./data/val_images/00914630_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914630_page-0.png
#   inflating: ./data/val_images/00911027_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00911027_page-0.png
#   inflating: ./data/val_images/00911474_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911474_page-1.png
#   inflating: ./data/val_images/00914616_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914616_page-1.png
#   inflating: ./data/val_images/00840674_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00840674_page-0.png
#   inflating: ./data/val_images/00914377_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914377_page-0.png
#   inflating: ./data/val_images/00914309_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914309_page-0.png
#   inflating: ./data/val_images/00911443_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00911443_page-0.png
#   inflating: ./data/val_images/00914310_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00914310_page-0.png
#   inflating: ./data/val_images/00910692_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00910692_page-1.png
#   inflating: ./data/val_images/00915279_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00915279_page-0.png
#   inflating: ./data/val_images/00912677_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00912677_page-1.png
#   inflating: ./data/val_images/00914345_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914345_page-1.png
#   inflating: ./data/val_images/00916694_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00916694_page-1.png
#   inflating: ./data/val_images/00911172_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911172_page-1.png
#   inflating: ./data/val_images/00917165_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917165_page-0.png
#   inflating: ./data/val_images/00839611_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00839611_page-0.png
#   inflating: ./data/val_images/00917652_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917652_page-0.png
#   inflating: ./data/val_images/00911015_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911015_page-1.png
#   inflating: ./data/val_images/00913934_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913934_page-0.png
#   inflating: ./data/val_images/00914987_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914987_page-1.png
#   inflating: ./data/val_images/00911816_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911816_page-1.png
#   inflating: ./data/val_images/00911039_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911039_page-1.png
#   inflating: ./data/val_images/00911526_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911526_page-1.png
#   inflating: ./data/val_images/00913933_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00913933_page-0.png
#   inflating: ./data/val_images/00917714_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917714_page-0.png
#   inflating: ./data/val_images/00917531_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917531_page-0.png
#   inflating: ./data/val_images/00917447_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00917447_page-0.png
#   inflating: ./data/val_images/00917749_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00917749_page-1.png
#   inflating: ./data/val_images/00914347_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914347_page-1.png
#   inflating: ./data/val_images/00912408_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00912408_page-0.png
#   inflating: ./data/val_images/00911390_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00911390_page-0.png
#   inflating: ./data/val_images/00839327_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00839327_page-0.png
#   inflating: ./data/val_images/00914637_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00914637_page-1.png
#   inflating: ./data/val_images/00911930_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911930_page-1.png
#   inflating: ./data/val_images/00911156_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00911156_page-1.png
#   inflating: ./data/val_images/00916935_page-1.png
#   inflating: ./__MACOSX/data/val_images/._00916935_page-1.png
#   inflating: ./data/val_images/00912526_page-0.png
#   inflating: ./__MACOSX/data/val_images/._00912526_page-0.png
#   inflating: ./data/train_images/01562500_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01562500_page-1.png
#   inflating: ./data/train_images/00830276_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830276_page-0.png
#   inflating: ./data/train_images/00845836_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00845836_page-0.png
#   inflating: ./data/train_images/00827223_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827223_page-0.png
#   inflating: ./data/train_images/01346455_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01346455_page-0.png
#   inflating: ./data/train_images/00830541_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830541_page-0.png
#   inflating: ./data/train_images/00836225_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00836225_page-1.png
#   inflating: ./data/train_images/01601510_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01601510_page-0.png
#   inflating: ./data/train_images/00831275_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831275_page-0.png
#   inflating: ./data/train_images/01413192_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01413192_page-0.png
#   inflating: ./data/train_images/00834276_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00834276_page-1.png
#   inflating: ./data/train_images/00831891_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00831891_page-1.png
#   inflating: ./data/train_images/01616961_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01616961_page-0.png
#   inflating: ./data/train_images/00842525_page-2.png
#   inflating: ./__MACOSX/data/train_images/._00842525_page-2.png
#   inflating: ./data/train_images/00826741_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00826741_page-0.png
#   inflating: ./data/train_images/00827208_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827208_page-0.png
#   inflating: ./data/train_images/01481191_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01481191_page-1.png
#   inflating: ./data/train_images/00834576_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00834576_page-0.png
#   inflating: ./data/train_images/01397263_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01397263_page-0.png
#   inflating: ./data/train_images/01323261_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01323261_page-0.png
#   inflating: ./data/train_images/00829118_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829118_page-0.png
#   inflating: ./data/train_images/01339280_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01339280_page-0.png
#   inflating: ./data/train_images/01455868_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01455868_page-0.png
#   inflating: ./data/train_images/01615135_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01615135_page-0.png
#   inflating: ./data/train_images/00828168_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00828168_page-0.png
#   inflating: ./data/train_images/00829688_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00829688_page-1.png
#   inflating: ./data/train_images/01596756_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01596756_page-0.png
#   inflating: ./data/train_images/01481597_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01481597_page-0.png
#   inflating: ./data/train_images/00833056_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833056_page-0.png
#   inflating: ./data/train_images/00828415_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00828415_page-0.png
#   inflating: ./data/train_images/00825081_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00825081_page-1.png
#   inflating: ./data/train_images/00833308_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833308_page-0.png
#   inflating: ./data/train_images/01517762_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01517762_page-1.png
#   inflating: ./data/train_images/01476944_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01476944_page-0.png
#   inflating: ./data/train_images/01360828_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01360828_page-0.png
#   inflating: ./data/train_images/00841100_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00841100_page-1.png
#   inflating: ./data/train_images/00825282_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825282_page-0.png
#   inflating: ./data/train_images/01566484_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01566484_page-0.png
#   inflating: ./data/train_images/00833281_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833281_page-0.png
#   inflating: ./data/train_images/00831144_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831144_page-0.png
#   inflating: ./data/train_images/00831084_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00831084_page-1.png
#   inflating: ./data/train_images/00827219_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827219_page-0.png
#   inflating: ./data/train_images/00825396_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825396_page-0.png
#   inflating: ./data/train_images/00836123_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00836123_page-0.png
#   inflating: ./data/train_images/01339499_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01339499_page-0.png
#   inflating: ./data/train_images/01592117_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01592117_page-0.png
#   inflating: ./data/train_images/00832256_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832256_page-0.png
#   inflating: ./data/train_images/00825623_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00825623_page-1.png
#   inflating: ./data/train_images/00835067_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835067_page-0.png
#   inflating: ./data/train_images/00837500_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00837500_page-1.png
#   inflating: ./data/train_images/01331405_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01331405_page-0.png
#   inflating: ./data/train_images/00834147_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00834147_page-0.png
#   inflating: ./data/train_images/01446642_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01446642_page-0.png
#   inflating: ./data/train_images/01424827_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01424827_page-0.png
#   inflating: ./data/train_images/01626393_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01626393_page-0.png
#   inflating: ./data/train_images/00844590_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00844590_page-0.png
#   inflating: ./data/train_images/00830703_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830703_page-0.png
#   inflating: ./data/train_images/00827117_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827117_page-0.png
#   inflating: ./data/train_images/01421595_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01421595_page-0.png
#   inflating: ./data/train_images/00843481_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00843481_page-1.png
#   inflating: ./data/train_images/00824829_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00824829_page-0.png
#   inflating: ./data/train_images/01396709_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01396709_page-0.png
#   inflating: ./data/train_images/01372560_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01372560_page-0.png
#   inflating: ./data/train_images/01508941_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01508941_page-0.png
#   inflating: ./data/train_images/01548979_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01548979_page-0.png
#   inflating: ./data/train_images/01502028_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01502028_page-0.png
#   inflating: ./data/train_images/01604855_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01604855_page-0.png
#   inflating: ./data/train_images/00827669_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827669_page-0.png
#   inflating: ./data/train_images/00846434_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00846434_page-0.png
#   inflating: ./data/train_images/00839316_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839316_page-0.png
#   inflating: ./data/train_images/00830169_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830169_page-0.png
#   inflating: ./data/train_images/01489247_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01489247_page-0.png
#   inflating: ./data/train_images/01525615_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01525615_page-0.png
#   inflating: ./data/train_images/00839416_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839416_page-0.png
#   inflating: ./data/train_images/00910606_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00910606_page-0.png
#   inflating: ./data/train_images/00827082_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827082_page-0.png
#   inflating: ./data/train_images/01382666_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01382666_page-0.png
#   inflating: ./data/train_images/00838488_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00838488_page-0.png
#   inflating: ./data/train_images/00834562_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00834562_page-1.png
#   inflating: ./data/train_images/00845364_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00845364_page-0.png
#   inflating: ./data/train_images/00827946_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827946_page-0.png
#   inflating: ./data/train_images/00828359_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00828359_page-0.png
#   inflating: ./data/train_images/00832988_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832988_page-0.png
#   inflating: ./data/train_images/01326042_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01326042_page-1.png
#   inflating: ./data/train_images/01330181_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01330181_page-0.png
#   inflating: ./data/train_images/00829722_page-2.png
#   inflating: ./__MACOSX/data/train_images/._00829722_page-2.png
#   inflating: ./data/train_images/00840874_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00840874_page-1.png
#   inflating: ./data/train_images/01434090_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01434090_page-0.png
#   inflating: ./data/train_images/00827696_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827696_page-0.png
#   inflating: ./data/train_images/01425017_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01425017_page-0.png
#   inflating: ./data/train_images/01385004_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01385004_page-1.png
#   inflating: ./data/train_images/00826090_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00826090_page-0.png
#   inflating: ./data/train_images/00829163_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829163_page-0.png
#   inflating: ./data/train_images/00831684_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831684_page-0.png
#   inflating: ./data/train_images/00831901_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831901_page-0.png
#   inflating: ./data/train_images/00830793_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830793_page-0.png
#   inflating: ./data/train_images/01577396_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01577396_page-0.png
#   inflating: ./data/train_images/00835270_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00835270_page-1.png
#   inflating: ./data/train_images/00832162_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00832162_page-1.png
#   inflating: ./data/train_images/00839759_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839759_page-0.png
#   inflating: ./data/train_images/00831809_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00831809_page-1.png
#   inflating: ./data/train_images/01382283_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01382283_page-0.png
#   inflating: ./data/train_images/00832662_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00832662_page-1.png
#   inflating: ./data/train_images/00824775_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00824775_page-1.png
#   inflating: ./data/train_images/00831270_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831270_page-0.png
#   inflating: ./data/train_images/01386640_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01386640_page-0.png
#   inflating: ./data/train_images/01550729_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01550729_page-0.png
#   inflating: ./data/train_images/00840262_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00840262_page-0.png
#   inflating: ./data/train_images/00832076_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832076_page-0.png
#   inflating: ./data/train_images/00833017_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833017_page-0.png
#   inflating: ./data/train_images/01614727_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01614727_page-0.png
#   inflating: ./data/train_images/01487218_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01487218_page-1.png
#   inflating: ./data/train_images/00826885_page-2.png
#   inflating: ./__MACOSX/data/train_images/._00826885_page-2.png
#   inflating: ./data/train_images/01627400_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01627400_page-1.png
#   inflating: ./data/train_images/01560503_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01560503_page-0.png
#   inflating: ./data/train_images/00825089_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825089_page-0.png
#   inflating: ./data/train_images/00844200_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00844200_page-1.png
#   inflating: ./data/train_images/00827715_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827715_page-0.png
#   inflating: ./data/train_images/01598214_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01598214_page-0.png
#   inflating: ./data/train_images/01508305_page-0.png
# ...
#   inflating: ./data/train_images/00835308_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835308_page-0.png
#   inflating: ./data/train_images/00825802_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825802_page-0.png
#   inflating: ./data/train_images/00839315_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839315_page-0.png
#   inflating: ./data/train_images/00843041_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00843041_page-0.png
#   inflating: ./data/train_images/00833126_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833126_page-0.png
#   inflating: ./data/train_images/01381847_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01381847_page-0.png
#   inflating: ./data/train_images/00827189_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827189_page-0.png
#   inflating: ./data/train_images/01370855_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01370855_page-0.png
#   inflating: ./data/train_images/01562999_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01562999_page-0.png
#   inflating: ./data/train_images/00832064_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832064_page-0.png
#   inflating: ./data/train_images/01615736_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01615736_page-0.png
#   inflating: ./data/train_images/01344731_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01344731_page-0.png
#   inflating: ./data/train_images/01596173_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01596173_page-0.png
#   inflating: ./data/train_images/00836147_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00836147_page-1.png
#   inflating: ./data/train_images/00828855_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00828855_page-0.png
#   inflating: ./data/train_images/00829920_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829920_page-0.png
#   inflating: ./data/train_images/01509659_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01509659_page-0.png
#   inflating: ./data/train_images/01480010_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01480010_page-0.png
#   inflating: ./data/train_images/01523908_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01523908_page-0.png
#   inflating: ./data/train_images/01476917_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01476917_page-0.png
#   inflating: ./data/train_images/00825284_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825284_page-0.png
#   inflating: ./data/train_images/00829102_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00829102_page-1.png
#   inflating: ./data/train_images/01477794_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01477794_page-0.png
#   inflating: ./data/train_images/00831319_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831319_page-0.png
#   inflating: ./data/train_images/00830650_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830650_page-0.png
#   inflating: ./data/train_images/00831106_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831106_page-0.png
#   inflating: ./data/train_images/00839630_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839630_page-0.png
#   inflating: ./data/train_images/01452378_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01452378_page-1.png
#   inflating: ./data/train_images/01370460_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01370460_page-0.png
#   inflating: ./data/train_images/00836576_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00836576_page-0.png
#   inflating: ./data/train_images/00827293_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827293_page-0.png
#   inflating: ./data/train_images/01473794_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01473794_page-1.png
#   inflating: ./data/train_images/01610227_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01610227_page-0.png
#   inflating: ./data/train_images/00830331_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00830331_page-1.png
#   inflating: ./data/train_images/00834711_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00834711_page-1.png
#   inflating: ./data/train_images/00833014_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833014_page-0.png
#   inflating: ./data/train_images/01592918_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01592918_page-1.png
#   inflating: ./data/train_images/00835106_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00835106_page-1.png
#   inflating: ./data/train_images/00840234_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00840234_page-0.png
#   inflating: ./data/train_images/00844991_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00844991_page-0.png
#   inflating: ./data/train_images/00835653_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00835653_page-1.png
#   inflating: ./data/train_images/00833966_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833966_page-0.png
#   inflating: ./data/train_images/00831739_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831739_page-0.png
#   inflating: ./data/train_images/00825289_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825289_page-0.png
#   inflating: ./data/train_images/01327411_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01327411_page-0.png
#   inflating: ./data/train_images/00826739_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00826739_page-0.png
#   inflating: ./data/train_images/00835319_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835319_page-0.png
#   inflating: ./data/train_images/01604657_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01604657_page-0.png
#   inflating: ./data/train_images/01451023_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01451023_page-0.png
#   inflating: ./data/train_images/01332256_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01332256_page-0.png
#   inflating: ./data/train_images/00836161_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00836161_page-0.png
#   inflating: ./data/train_images/01502840_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01502840_page-1.png
#   inflating: ./data/train_images/00844608_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00844608_page-0.png
#   inflating: ./data/train_images/00837741_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00837741_page-0.png
#   inflating: ./data/train_images/00832514_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832514_page-0.png
#   inflating: ./data/train_images/01547229_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01547229_page-0.png
#   inflating: ./data/train_images/00844503_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00844503_page-0.png
#   inflating: ./data/train_images/00839418_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00839418_page-1.png
#   inflating: ./data/train_images/00838900_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00838900_page-0.png
#   inflating: ./data/train_images/01387343_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01387343_page-0.png
#   inflating: ./data/train_images/00835589_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835589_page-0.png
#   inflating: ./data/train_images/01554645_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01554645_page-0.png
#   inflating: ./data/train_images/01400324_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01400324_page-0.png
#   inflating: ./data/train_images/01327879_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01327879_page-0.png
#   inflating: ./data/train_images/00833963_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00833963_page-1.png
#   inflating: ./data/train_images/01523814_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01523814_page-1.png
#   inflating: ./data/train_images/00827918_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827918_page-0.png
#   inflating: ./data/train_images/00829404_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829404_page-0.png
#   inflating: ./data/train_images/00835355_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835355_page-0.png
#   inflating: ./data/train_images/00841857_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00841857_page-0.png
#   inflating: ./data/train_images/01311266_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01311266_page-0.png
#   inflating: ./data/train_images/01479846_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01479846_page-1.png
#   inflating: ./data/train_images/00835223_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835223_page-0.png
#   inflating: ./data/train_images/00825178_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00825178_page-1.png
#   inflating: ./data/train_images/00840977_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00840977_page-0.png
#   inflating: ./data/train_images/00832678_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832678_page-0.png
#   inflating: ./data/train_images/00840032_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00840032_page-0.png
#   inflating: ./data/train_images/01624951_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01624951_page-0.png
#   inflating: ./data/train_images/00826965_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00826965_page-0.png
#   inflating: ./data/train_images/00838180_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00838180_page-0.png
#   inflating: ./data/train_images/01503508_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01503508_page-0.png
#   inflating: ./data/train_images/01441217_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01441217_page-0.png
#   inflating: ./data/train_images/00830275_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00830275_page-0.png
#   inflating: ./data/train_images/00825960_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825960_page-0.png
#   inflating: ./data/train_images/01565553_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01565553_page-0.png
#   inflating: ./data/train_images/00839768_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839768_page-0.png
#   inflating: ./data/train_images/00843469_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00843469_page-0.png
#   inflating: ./data/train_images/00846314_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00846314_page-0.png
#   inflating: ./data/train_images/01331561_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01331561_page-0.png
#   inflating: ./data/train_images/00827217_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00827217_page-0.png
#   inflating: ./data/train_images/01479355_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01479355_page-0.png
#   inflating: ./data/train_images/00824963_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00824963_page-0.png
#   inflating: ./data/train_images/01355023_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01355023_page-0.png
#   inflating: ./data/train_images/01495806_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01495806_page-0.png
#   inflating: ./data/train_images/01527188_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01527188_page-0.png
#   inflating: ./data/train_images/01575698_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01575698_page-0.png
#   inflating: ./data/train_images/01578499_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01578499_page-0.png
#   inflating: ./data/train_images/00839204_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839204_page-0.png
#   inflating: ./data/train_images/00835064_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835064_page-0.png
#   inflating: ./data/train_images/01404680_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01404680_page-0.png
#   inflating: ./data/train_images/00828557_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00828557_page-1.png
#   inflating: ./data/train_images/01403379_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01403379_page-0.png
#   inflating: ./data/train_images/00833695_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833695_page-0.png
#   inflating: ./data/train_images/00841979_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00841979_page-0.png
#   inflating: ./data/train_images/00826426_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00826426_page-0.png
#   inflating: ./data/train_images/01383077_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01383077_page-0.png
#   inflating: ./data/train_images/00837176_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00837176_page-0.png
#   inflating: ./data/train_images/01521299_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01521299_page-0.png
#   inflating: ./data/train_images/00831835_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831835_page-0.png
#   inflating: ./data/train_images/00832281_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00832281_page-1.png
#   inflating: ./data/train_images/01515190_page-1.png
#   inflating: ./__MACOSX/data/train_images/._01515190_page-1.png
#   inflating: ./data/train_images/01421331_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01421331_page-0.png
#   inflating: ./data/train_images/01448138_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01448138_page-0.png
#   inflating: ./data/train_images/00829616_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829616_page-0.png
#   inflating: ./data/train_images/00832500_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00832500_page-0.png
#   inflating: ./data/train_images/00827863_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00827863_page-1.png
#   inflating: ./data/train_images/00829197_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829197_page-0.png
#   inflating: ./data/train_images/01628718_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01628718_page-0.png
#   inflating: ./data/train_images/00835267_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00835267_page-0.png
#   inflating: ./data/train_images/00840933_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00840933_page-0.png
#   inflating: ./data/train_images/00836946_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00836946_page-0.png
#   inflating: ./data/train_images/00825879_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825879_page-0.png
#   inflating: ./data/train_images/00839646_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00839646_page-0.png
#   inflating: ./data/train_images/01531783_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01531783_page-0.png
#   inflating: ./data/train_images/00831147_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00831147_page-0.png
#   inflating: ./data/train_images/00829668_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00829668_page-0.png
#   inflating: ./data/train_images/01540292_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01540292_page-0.png
#   inflating: ./data/train_images/00844904_page-1.png
#   inflating: ./__MACOSX/data/train_images/._00844904_page-1.png
#   inflating: ./data/train_images/01544791_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01544791_page-0.png
#   inflating: ./data/train_images/00825617_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00825617_page-0.png
#   inflating: ./data/train_images/00833055_page-0.png
#   inflating: ./__MACOSX/data/train_images/._00833055_page-0.png
#   inflating: ./data/train_images/01537586_page-0.png
#   inflating: ./__MACOSX/data/train_images/._01537586_page-0.png

# %% [markdown]
# # Data Augmentation

# %%
import pickle
import tqdm
import os

data_dir = './data'
noised_dir = './data/aug_images'

doc_info_dir = './data'

with open(f'{doc_info_dir}/train_doc_info.pkl', 'rb') as f:
    train_doc_info = pickle.load(f)
with open(f'{doc_info_dir}/val_doc_info.pkl', 'rb') as f:
    val_doc_info = pickle.load(f)

image_dirs = ['train_images', 'val_images']

def rotate_bbox(bbox, angle):

    # 각도를 라디안으로 변환
    angle_rad = np.deg2rad(angle)

    # 경계 상자의 중심점 계산
    center_x = bbox[0] + bbox[2] / 2
    center_y = bbox[1] + bbox[3] / 2

    # 각 모서리의 원래 좌표 계산
    corners = [
        (bbox[0], bbox[1]),  # 왼쪽 상단 모서리
        (bbox[0] + bbox[2], bbox[1]),  # 오른쪽 상단 모서리
        (bbox[0] + bbox[2], bbox[1] + bbox[3]),  # 오른쪽 하단 모서리
        (bbox[0], bbox[1] + bbox[3])  # 왼쪽 하단 모서리
    ]

    # 각 모서리를 회전시킨 새 좌표 계산
    new_corners = [(
            center_x + (corner[0] - center_x) * np.cos(angle_rad) - (corner[1] - center_y) * np.sin(angle_rad),
            center_y + (corner[0] - center_x) * np.sin(angle_rad) + (corner[1] - center_y) * np.cos(angle_rad)
        ) for corner in corners]

    # 회전 후 새 경계 상자의 좌표를 계산하여 반환
    min_x = min(corner[0] for corner in new_corners)
    min_y = min(corner[1] for corner in new_corners)
    max_x = max(corner[0] for corner in new_corners)
    max_y = max(corner[1] for corner in new_corners)

    # 회전된 경계 상자의 'x, y, width, height' 형태로 변환하여 반환
    return [min_x, min_y, max_x - min_x, max_y - min_y]

for image_dir in image_dirs:
    if image_dir == 'train_images':
        doc_info = train_doc_info
    else:
        doc_info = val_doc_info

    os.makedirs(os.path.join(noised_dir, image_dir), exist_ok=True)

    for filename in tqdm.tqdm(os.listdir(os.path.join(data_dir, image_dir)), desc="Processing images"):
        image_path = os.path.join(data_dir, image_dir, filename)
        noised_path = os.path.join(noised_dir, image_dir, filename)
        angle = combined_image_processing(image_path, noised_path)

        image_name = filename.split('.')[0]

        for object_id, object in doc_info[image_name]['objects'].items():
            new_bbox = rotate_bbox(object['bbox'], angle)
            doc_info[image_name]['objects'][object_id]['bbox'] = new_bbox

    if image_dir == 'train_images':
        with open(f'{doc_info_dir}/aug_train_doc_info.pkl', 'wb') as f:
            pickle.dump(doc_info, f)
    else:
        with open(f'{doc_info_dir}/aug_val_doc_info.pkl', 'wb') as f:
            pickle.dump(doc_info, f)
# Out:
# Processing images: 100%|██████████| 535/535 [01:53<00:00,  4.70it/s]
# Processing images: 100%|██████████| 76/76 [00:15<00:00,  5.00it/s]

# %%
from PIL import Image, ImageFilter
import numpy as np
import cv2

def add_noise_and_rotate(image_path, output_path):
    # Load the image
    image = Image.open(image_path)

    # Randomly choose a small angle to rotate
    angle = np.random.uniform(-2, 2)  # Rotate between -2 and 2 degrees
    rotated_image = image.rotate(angle, expand=False, fillcolor='white', resample=Image.BICUBIC)

    # Convert the image to numpy array
    image_array = np.asarray(rotated_image, dtype=np.uint8)

    # Generate Gaussian noise
    mean = 0
    std_dev = 5  # Standard deviation of the noise
    noise = np.random.normal(mean, std_dev, image_array.shape[:2])

    # Add noise to the image
    noisy_image_array = image_array + noise[:, :, None]
    noisy_image_array = np.clip(noisy_image_array, 0, 255)  # Ensure values are within valid range

    # Convert array back to image
    noisy_image = Image.fromarray(noisy_image_array.astype(np.uint8))

    # Apply dilation and blurring
    # noisy_image = noisy_image.filter(ImageFilter.CONTOUR())  # Dilation
    noisy_image = noisy_image.filter(ImageFilter.GaussianBlur(radius=0.3))  # Blur

    # Save the modified image
    noisy_image.save(output_path)

def erode_text(image_path, output_path, erode_prob=0.02):
    # 이미지를 그레이스케일로 로드
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # 픽셀 유실 처리
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            # 검은색 픽셀(가정하에)을 하얀색으로 변경
            if image[i, j] < 128 and random.random() < 0.05:
                image[i, j] = 255  # 검은색 픽셀을 하얀색으로 변경

    # 결과 이미지 저장
    cv2.imwrite(output_path, image)

def combined_image_processing(image_path, output_path):
    # 이미지를 PIL로 로드하고 회전
    image = Image.open(image_path)
    angle = np.random.uniform(-2, 2)  # Rotate between -2 and 2 degrees
    rotated_image = image.rotate(angle, expand=False, fillcolor='white', resample=Image.BICUBIC)

    # PIL 이미지를 OpenCV 형식으로 변환
    rotated_image_cv = cv2.cvtColor(np.array(rotated_image), cv2.COLOR_RGB2GRAY)

    # Gaussian noise 추가
    mean = 0
    std_dev = 5  # Standard deviation of the noise
    noise = np.random.normal(mean, std_dev, rotated_image_cv.shape)
    noisy_image_array = rotated_image_cv + noise
    noisy_image_array = np.clip(noisy_image_array, 0, 255)  # Ensure values are within valid range

    # 픽셀 유실 처리
    for i in range(noisy_image_array.shape[0]):
        for j in range(noisy_image_array.shape[1]):
            if noisy_image_array[i, j] < 128 and random.random() < 0.05:
                noisy_image_array[i, j] = 255  # 검은색 픽셀을 하얀색으로 변경

    # 블러링 적용
    final_image = cv2.GaussianBlur(noisy_image_array.astype(np.uint8), (3, 3), 0.3)

    # 결과 이미지 저장
    cv2.imwrite(output_path, final_image)

    return angle

# %% [markdown]
# # Feature Extraction
#
# We newly extracted visual/textual feature for modeling

# %%
import pickle

with open('data/train_doc_info.pkl','rb') as f:
    train_doc_info = pickle.load(f)

with open('data/val_doc_info.pkl','rb') as f:
    val_doc_info = pickle.load(f)

with open('data/test_doc_info.pkl','rb') as f:
    test_doc_info = pickle.load(f)

with open('data/printed_doc_info.pkl','rb') as f:
    printed_doc_info = pickle.load(f)

with open('data/aug_train_doc_info.pkl','rb') as f:
    aug_train_doc_info = pickle.load(f)

with open('data/aug_val_doc_info.pkl','rb') as f:
    aug_val_doc_info = pickle.load(f)

# %%
import torch
from torchvision import models, transforms
from PIL import Image
import os
from transformers import AutoModel, AutoTokenizer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 모델과 전처리 함수를 전역 변수로 선언하여 매번 로드하지 않도록 합니다
visual_model = models.resnet101(pretrained=True)
visual_model = torch.nn.Sequential(*list(visual_model.children())[:-2])
visual_model = visual_model.to(device)
visual_model.eval()

visual_preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

tokenizer = AutoTokenizer.from_pretrained('microsoft/deberta-v3-large')
textual_model = AutoModel.from_pretrained('microsoft/deberta-v3-large')
textual_model = textual_model.to(device)
textual_model.eval()

def extract_visual_features_batch(image_paths, boundary_boxes=None):
    batch_size = len(image_paths)
    images = []

    for i, image_path in enumerate(image_paths):
        image = Image.open(image_path).convert('RGB')
        if boundary_boxes is not None:
            image = image.crop(boundary_boxes[i])
        image = visual_preprocess(image)
        images.append(image)

    images = torch.stack(images).to(device)

    with torch.no_grad():
        features = visual_model(images)

    # features는 [batch_size, 2048, 7, 7] 크기의 텐서로 반환됨
    # [batch_size, 2048]로 변환
    features = torch.nn.functional.adaptive_avg_pool2d(features, (1, 1))
    features = features.view(batch_size, -1)

    return features.cpu().numpy()

def extract_textual_features_batch(texts):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)

    with torch.no_grad():
        outputs = textual_model(**inputs)

    textual_features = outputs.last_hidden_state[:, 0, :].cpu().numpy()

    return textual_features
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:01<00:00, 161MB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:562: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/874M [00:00<?, ?B/s]

# %%
from tqdm import tqdm
import os
import pickle
import numpy as np

def process_batch(batch, img_dir, data_dir):
    results = []
    for img_name, img_info in batch:
        if 'objects' not in img_info:
            print(f"Warning: 'objects' not found in image info for {img_name}")
            continue

        for obj_idx, obj_info in img_info['objects'].items():
            if 'text' not in obj_info or 'bbox' not in obj_info:
                print(f"Warning: 'text' or 'bbox' not found in object info for {img_name}, object {obj_idx}")
                continue

            text = obj_info['text']
            bbox = obj_info['bbox']

            # bbox in form of [[x0, y0], [x0+w, y0], [x0+w, y0+h], [x0, y0+h]]
            # Convert to [x0, y0, x1, y1]
            boundary_box = [bbox[0], bbox[1], bbox[2] + bbox[0], bbox[3] + bbox[1]]

            results.append({
                'img_name': img_name,
                'obj_idx': obj_idx,
                'text': text,
                'bbox': bbox,
                'boundary_box': boundary_box,
                'img_path': os.path.join(data_dir, img_dir, f"{img_name}.png")
            })

    if not results:
        print(f"Warning: No valid objects found in this batch")
        return batch

    visual_features = extract_visual_features_batch([r['img_path'] for r in results], [r['boundary_box'] for r in results])
    textual_features = extract_textual_features_batch([r['text'] for r in results])

    for i, result in enumerate(results):
        img_name = result['img_name']
        obj_idx = result['obj_idx']

        if img_name not in dict(batch):
            print(f"Warning: {img_name} not found in batch")
            continue

        img_info = dict(batch)[img_name]
        if 'objects' not in img_info:
            img_info['objects'] = {}

        if obj_idx not in img_info['objects']:
            img_info['objects'][obj_idx] = {}

        img_info['objects'][obj_idx]['bbox'] = result['bbox']
        img_info['objects'][obj_idx]['visual_feature'] = visual_features[i].tolist()
        img_info['objects'][obj_idx]['textual_feature'] = textual_features[i].tolist()

    return batch

datasets = {
    'train_images': train_doc_info,
    'val_images': val_doc_info,
    'test_images': test_doc_info,
    'printed_images': printed_doc_info,
    'aug_images/train_images': aug_train_doc_info,
    'aug_images/val_images': aug_val_doc_info
}

save_file_directory = 'doc_info'
os.makedirs(save_file_directory, exist_ok=True)

save_file_path = ['train_doc_info.pkl', 'val_doc_info.pkl', 'test_doc_info.pkl', 'printed_doc_info.pkl', 'aug_train_doc_info.pkl', 'aug_val_doc_info.pkl']

process_batch_size = 8

for i, (img_dir, doc_info) in enumerate(datasets.items()):
    batches = [list(doc_info.items())[i:i+process_batch_size] for i in range(0, len(doc_info), process_batch_size)]

    for batch in tqdm(batches, desc=f"Processing {img_dir}"):
        processed_batch = process_batch(batch, img_dir, data_dir)

        for img_name, img_info in processed_batch:
            doc_info[img_name] = img_info

    with open(f'{save_file_directory}/{save_file_path[i]}', 'wb') as f:
        pickle.dump(doc_info, f)

    print(f'{save_file_path[i]} file is saved!')
# Out:
# Processing train_images: 100%|██████████| 67/67 [07:55<00:00,  7.09s/it]
# train_doc_info.pkl file is saved!
# Processing val_images: 100%|██████████| 10/10 [01:09<00:00,  6.93s/it]
# val_doc_info.pkl file is saved!
# Processing test_images: 100%|██████████| 19/19 [02:08<00:00,  6.76s/it]
# test_doc_info.pkl file is saved!
# Processing printed_images: 100%|██████████| 7/7 [01:02<00:00,  8.98s/it]
# printed_doc_info.pkl file is saved!
# Processing aug_images/train_images: 100%|██████████| 67/67 [08:12<00:00,  7.36s/it]
# aug_train_doc_info.pkl file is saved!
# Processing aug_images/val_images: 100%|██████████| 10/10 [01:12<00:00,  7.29s/it]
# aug_val_doc_info.pkl file is saved!

# %%
import gc

def clear_gpu_memory():
    global visual_model, textual_model

    # 모델을 CPU로 이동
    visual_model = visual_model.cpu()
    textual_model = textual_model.cpu()

    del visual_model
    del textual_model

    # CUDA 캐시 정리
    torch.cuda.empty_cache()

    # 가비지 컬렉션 실행
    gc.collect()

# 특징 추출이 완료된 후 이 함수를 호출
clear_gpu_memory()

print("GPU memory cleared and models moved to CPU.")
# Out:
# GPU memory cleared and models moved to CPU.

# %% [markdown]
# ## Loading Dataset

# %%
import pandas as pd

train_df = pd.read_csv('data/train_dataframe.csv')
train_df.rename(columns={'label(global_id)': 'label'}, inplace=True)
val_df = pd.read_csv('data/val_dataframe.csv')
val_df.rename(columns={'label(global_id)': 'label'}, inplace=True)

# %%
import pickle

with open('doc_info/train_doc_info.pkl','rb') as f:
  train_doc_info = pickle.load(f)
with open('doc_info/val_doc_info.pkl','rb') as f:
  val_doc_info = pickle.load(f)

# %%
with open(f'doc_info/aug_train_doc_info.pkl', "rb") as f:
    aug_train_doc_info = pickle.load(f)

with open(f'doc_info/aug_val_doc_info.pkl', "rb") as f:
    aug_val_doc_info = pickle.load(f)

# %% [markdown]
# ## Dataloader

# %%
from torch.utils.data import Dataset

class formnlu_taskb(Dataset):
    def __init__(self, dataframe, doc_info, tokenizer, max_question_length=50, max_obj_num=35):
        self.doc = dataframe.file
        self.answer = dataframe.label
        self.text = dataframe.key_fix_text
        self.tokenizer = tokenizer
        self.doc_info = doc_info
        self.max_question_length = max_question_length
        self.max_obj_num = max_obj_num
        self.feature_obj_num = max_obj_num*2

    def __len__(self):
        return len(self.doc)

    def __getitem__(self, idx):
        doc_id = self.doc[idx]
        doc_id = doc_id.replace('.png','')
        text = self.text[idx]
        inputs = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_question_length,
            padding='max_length',
            return_token_type_ids=True
        )

        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]

        answer_id = self.answer[idx]
        seq_id = 0
        target_ids = []
        page = self.doc_info[doc_id]
        textual_feature_list = []
        visual_feature_list = []
        bbox_list = []
        obj_mask = []
        obj_token_type_ids = []

        for i, (obj_local_id, obj) in enumerate(page['objects'].items()):
            global_id = obj['global_id']
            if int(global_id) == int(answer_id):
                target_ids.append(1)
            else:
                target_ids.append(0)
            textual_feature_list.append(obj['textual_feature'])
            visual_feature_list.append(obj['visual_feature'])
            bbox_list.append(obj['bbox'])
            obj_mask.append(1)
            obj_token_type_ids.append(1)

        if len(textual_feature_list) >= self.max_obj_num:
            textual_feature_list = textual_feature_list[:self.max_obj_num]
            visual_feature_list = visual_feature_list[:self.max_obj_num]
            bbox_list = bbox_list[:self.max_obj_num]
            obj_mask = obj_mask[:self.max_obj_num]
            obj_token_type_ids = obj_token_type_ids[:self.max_obj_num]
            target_ids = target_ids[:self.max_obj_num]
        else:
            textual_feature_list.extend([[0.0]*1024]*(self.max_obj_num-len(textual_feature_list)))
            visual_feature_list.extend([[0.0]*2048]*(self.max_obj_num-len(visual_feature_list)))
            bbox_list.extend([[0.0]*4]*(self.max_obj_num-len(bbox_list)))
            obj_mask.extend([0]*(self.max_obj_num-len(obj_mask)))
            obj_token_type_ids.extend([1]*(self.max_obj_num-len(obj_token_type_ids)))
            target_ids.extend([-1]*(self.max_obj_num-len(target_ids)))

        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.float),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'textual_feature': torch.tensor(textual_feature_list, dtype=torch.float),
            'visual_feature': torch.tensor(visual_feature_list, dtype=torch.float),
            'bbox': torch.tensor(bbox_list, dtype=torch.float),
            'target_ids': torch.tensor(target_ids, dtype=torch.float),
            'obj_mask': torch.tensor(obj_mask, dtype=torch.long),
            'file': self.doc[idx]
        }

# %% [markdown]
# ## Modeling

# %%
import torch
from torch import nn
from transformers import LxmertModel

# Visual-Textual Fusion Transformer
class VTFT(nn.Module):
    def __init__(self, model_path):
        super(VTFT, self).__init__()
        self.text_proj = nn.Linear(1024, 2048)
        self.lxmert = LxmertModel.from_pretrained(model_path)
        self.fc = nn.Linear(768*2, 2048)
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(2048, 1)

    def forward(self, input_ids, attention_mask, token_type_ids, textual_feature, visual_feats, visual_pos, obj_attention_mask,):
        batch_size = input_ids.shape[0]

        textual_feature = self.text_proj(textual_feature)

        feature = torch.cat([textual_feature, visual_feats], dim=-1).view(batch_size, -1, 2048)
        pos = torch.cat([visual_pos, visual_pos], dim=-1).view(batch_size, -1, 4)
        mask = torch.cat([obj_attention_mask.unsqueeze(-1), obj_attention_mask.unsqueeze(-1)], dim=-1).view(batch_size, -1)

        outputs = self.lxmert(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids,
                              visual_feats=feature, visual_pos=pos, visual_attention_mask=mask)
        cross_outputs = outputs.vision_output.view(batch_size, -1, 768*2)
        output = self.fc(cross_outputs)
        output = self.dropout(output)
        logits = self.classifier(output)
        return logits

# %%
from torch import cuda
from transformers import AutoTokenizer

device = 'cuda' if cuda.is_available() else 'cpu'
print(device)

tokenizer_path = 'unc-nlp/lxmert-base-uncased'
model_name = 'unc-nlp/lxmert-base-uncased'

model_class = VTFT

tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = model_class(model_name).to(device)
model
# Out:
# cuda
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the model checkpoint at unc-nlp/lxmert-base-uncased were not used when initializing LxmertModel: ['answer_head.logit_fc.0.bias', 'answer_head.logit_fc.0.weight', 'answer_head.logit_fc.2.bias', 'answer_head.logit_fc.2.weight', 'answer_head.logit_fc.3.bias', 'answer_head.logit_fc.3.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'obj_predict_head.decoder_dict.attr.bias', 'obj_predict_head.decoder_dict.attr.weight', 'obj_predict_head.decoder_dict.feat.bias', 'obj_predict_head.decoder_dict.feat.weight', 'obj_predict_head.decoder_dict.obj.bias', 'obj_predict_head.decoder_dict.obj.weight', 'obj_predict_head.transform.LayerNorm.bias', 'obj_predict_head.transform.LayerNorm.weight', 'obj_predict_head.transform.dense.bias', 'obj_predict_head.transform.dense.weight']
# - This IS expected if you are initializing LxmertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LxmertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# VTFT(
#   (text_proj): Linear(in_features=1024, out_features=2048, bias=True)
#   (lxmert): LxmertModel(
#     (embeddings): LxmertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768, padding_idx=0)
#       (token_type_embeddings): Embedding(2, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LxmertEncoder(
#       (visn_fc): LxmertVisualFeatureEncoder(
#         (visn_fc): Linear(in_features=2048, out_features=768, bias=True)
#         (visn_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (box_fc): Linear(in_features=4, out_features=768, bias=True)
#         (box_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (layer): ModuleList(
#         (0-8): 9 x LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (x_layers): ModuleList(
#         (0-4): 5 x LxmertXLayer(
#           (visual_attention): LxmertCrossAttentionLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (r_layers): ModuleList(
#         (0-4): 5 x LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LxmertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=1536, out_features=2048, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=2048, out_features=1, bias=True)
# )

# %%
from torch.utils.data import Subset

train_set = formnlu_taskb(train_df,train_doc_info, tokenizer)
aug_train_set = formnlu_taskb(train_df, aug_train_doc_info, tokenizer)

indices = np.random.permutation(len(aug_train_set))
subset_indices = indices[:int(len(aug_train_set) * aug_data)]
random_train_subset = Subset(aug_train_set, subset_indices)

valid_set = formnlu_taskb(val_df,val_doc_info, tokenizer)
aug_valid_set = formnlu_taskb(val_df, aug_val_doc_info, tokenizer)

indices = np.random.permutation(len(aug_valid_set))
subset_indices = indices[:int(len(aug_valid_set) * aug_data)]
random_valid_subset = Subset(aug_valid_set, subset_indices)

# %%
from torch.utils.data import ConcatDataset, DataLoader

train_set = ConcatDataset([train_set, random_train_subset, valid_set, random_valid_subset])
valid_set = ConcatDataset([valid_set, random_valid_subset])

train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_dataloader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

warmup_steps = 0.1 * len(train_dataloader)
loss_function = torch.nn.BCEWithLogitsLoss()
optimizer = AdamW(params=model.parameters(), lr=lr, weight_decay=0.1)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=len(train_dataloader)*epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
import os

model_path = f'./models/{model_class.__name__}'

os.makedirs(model_path, exist_ok=True)

def save_model(model, epoch, path):
    save_path = f'{model_path}/epoch{epoch}.pth'
    print(save_path)
    torch.save(model.state_dict(), save_path)
    print(f"Model saved to {path}_epoch{epoch}")

# %%
from tqdm import tqdm
import torch.nn.functional as F

# Defining the training function on the 80% of the dataset for tuning the distilbert model
def calcuate_exact_match_correct(probs, targets, obj_mask, thresholds=0.5):
    probs[probs>thresholds] = 1
    probs[probs<=thresholds] = 0
    probs[obj_mask==0] = -1

    corrects = torch.sum(torch.eq(probs, targets),dim=1)
    n_corrects = torch.sum(corrects==targets.shape[1]) # 50

    return n_corrects.item()

# Creating the loss function and optimizer
def train(model, epoch, train_dataloader, loss_function, optimizer, scheduler, device):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    model.train()

    for _,data in tqdm(enumerate(train_dataloader, 0)):
        ids = data['ids'].to(device)
        mask = data['mask'].to(device)
        token_type_ids = data['token_type_ids'].to(device)
        target_ids = data['target_ids'].to(device)
        textual_feature = data['textual_feature'].to(device)
        visual_feature = data['visual_feature'].to(device)
        bbox = data['bbox'].to(device)
        obj_mask = data['obj_mask'].to(device)

        logits = model(input_ids=ids, attention_mask=mask, token_type_ids=token_type_ids, textual_feature=textual_feature,
                       visual_feats=visual_feature, obj_attention_mask=obj_mask, visual_pos=bbox).view(ids.shape[0],-1)
        probs = F.sigmoid(logits)

        flat_target_ids = torch.flatten(target_ids)
        flat_logits = torch.flatten(logits)

        flat_logits = flat_logits[flat_target_ids!=-1]
        flat_target_ids = flat_target_ids[flat_target_ids!=-1]

        loss = loss_function(flat_logits, flat_target_ids)
        tr_loss += loss.item()

        n_correct += calcuate_exact_match_correct(probs, target_ids, obj_mask)

        nb_tr_steps += 1
        nb_tr_examples+=target_ids.size(0)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = n_correct/nb_tr_examples
    print(f"Training Loss of Epoch {epoch}: {epoch_loss}")
    print(f"Training Accuracy of Epoch {epoch}: {epoch_accu}")

    return epoch_loss, epoch_accu

# %%
import torch.nn.functional as F

def evaluate(model, valid_dataloader, device):
    n_correct = 0
    nb_tr_examples = 0
    model.eval()
    for _,data in tqdm(enumerate(valid_dataloader, 0)):
        ids = data['ids'].to(device)
        mask = data['mask'].to(device)
        token_type_ids = data['token_type_ids'].to(device)
        target_ids = data['target_ids'].to(device)
        textual_feature = data['textual_feature'].to(device)
        visual_feature = data['visual_feature'].to(device)
        bbox = data['bbox'].to(device)
        obj_mask = data['obj_mask'].to(device)

        logits = model(input_ids=ids, attention_mask=mask, token_type_ids=token_type_ids, textual_feature=textual_feature,
                       visual_feats=visual_feature, obj_attention_mask=obj_mask, visual_pos=bbox).view(ids.shape[0],-1)
        probs = F.sigmoid(logits)

        n_correct += calcuate_exact_match_correct(probs, target_ids, obj_mask)
        nb_tr_examples+=target_ids.size(0)

    epoch_accu = n_correct/nb_tr_examples
    print(f"Validation Accuracy Epoch: {epoch_accu}")

    return epoch_accu

# %%
best_val_acc = 0
patience_counter = 0
best_epoch = 0

for epoch in range(epochs):
    train_loss, train_acc = train(model, epoch, train_dataloader, loss_function, optimizer, scheduler, device)
    val_acc = evaluate(model, valid_dataloader, device)

    if early_stop:
        # Early stopping condition
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            patience_counter = 0
            best_epoch = epoch
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break
        else:
            print("No Early stopping")
    else:
        best_epoch = epoch

save_model(model, best_epoch, model_path)
# Out:
# 455it [07:37,  1.01s/it]
# Training Loss of Epoch 0: 0.0752616440079042
# Training Accuracy of Epoch 0: 0.3497733205110592
# 57it [00:29,  1.97it/s]
# Validation Accuracy Epoch: 0.7057522123893806
# 455it [07:33,  1.00it/s]
# Training Loss of Epoch 1: 0.021232556235966284
# Training Accuracy of Epoch 1: 0.7740761093556807
# 57it [00:29,  1.95it/s]
# Validation Accuracy Epoch: 0.9430309734513275
# 455it [07:34,  1.00it/s]
# Training Loss of Epoch 2: 0.010551813896233728
# Training Accuracy of Epoch 2: 0.9040390163483996
# 57it [00:29,  1.93it/s]
# Validation Accuracy Epoch: 0.9823008849557522
# 455it [07:33,  1.00it/s]
# Training Loss of Epoch 3: 0.004898644526822334
# Training Accuracy of Epoch 3: 0.957755186151944
# 57it [00:29,  1.93it/s]
# Validation Accuracy Epoch: 0.9950221238938053
# 455it [07:34,  1.00it/s]
# Training Loss of Epoch 4: 0.003459507328919314
# Training Accuracy of Epoch 4: 0.9694326143701057
# 57it [00:29,  1.96it/s]
# Validation Accuracy Epoch: 0.9977876106194691
# 455it [07:34,  1.00it/s]
# Training Loss of Epoch 5: 0.0026634992344842542
# Training Accuracy of Epoch 5: 0.9774694326143701
# 57it [00:28,  1.98it/s]
# Validation Accuracy Epoch: 0.9983407079646017
# 455it [07:35,  1.00s/it]
# Training Loss of Epoch 6: 0.0015053450015709662
# Training Accuracy of Epoch 6: 0.9872235197142465
# 57it [00:29,  1.91it/s]
# Validation Accuracy Epoch: 0.9961283185840708
# 455it [07:32,  1.01it/s]
# Training Loss of Epoch 7: 0.0008493812107040107
# Training Accuracy of Epoch 7: 0.9921005632641846
# 57it [00:28,  1.98it/s]
# Validation Accuracy Epoch: 0.9994469026548672
# 455it [07:33,  1.00it/s]
# Training Loss of Epoch 8: 0.0004844627900343607
# Training Accuracy of Epoch 8: 0.9964967715345514
# 57it [00:29,  1.94it/s]
# Validation Accuracy Epoch: 1.0
# 455it [07:31,  1.01it/s]
# Training Loss of Epoch 9: 0.00038774028817737576
# Training Accuracy of Epoch 9: 0.9972523698310207
# 57it [00:28,  1.98it/s]
# Validation Accuracy Epoch: 1.0
# ./models/VTFT/epoch9.pth
# Model saved to ./models/VTFT_epoch9

# %% [markdown]
# ## Evaluation

# %%
class formnlu_taskb_test(Dataset):
    def __init__(self, dataframe, doc_info, tokenizer, max_question_length=100, max_obj_num=35):
        self.doc = dataframe.file
        self.text = dataframe.key_fix_text
        self.tokenizer = tokenizer
        self.doc_info = doc_info
        self.max_question_length = max_question_length
        self.max_obj_num = max_obj_num
        self.feature_obj_num = max_obj_num*2

    def __len__(self):
        return len(self.doc)

    def __getitem__(self, idx):
        doc_id = self.doc[idx]
        doc_id = doc_id.replace('.png', '')

        if doc_id not in self.doc_info:
            return None

        text = self.text[idx]
        inputs = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_question_length,
            padding='max_length',
            return_token_type_ids=True
        )

        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]

        page = self.doc_info[doc_id]
        textual_feature_list = []
        visual_feature_list = []
        bbox_list = []
        obj_mask = []

        for i, (obj_local_id, obj) in enumerate(page['objects'].items()):
            textual_feature_list.append(obj['textual_feature'])
            visual_feature_list.append(obj['visual_feature'])
            bbox_list.append(obj['bbox'])
            obj_mask.append(1)

        if len(textual_feature_list) >= self.max_obj_num:
            textual_feature_list = textual_feature_list[:self.max_obj_num]
            visual_feature_list = visual_feature_list[:self.max_obj_num]
            bbox_list = bbox_list[:self.max_obj_num]
            obj_mask = obj_mask[:self.max_obj_num]
        else:
            textual_feature_list.extend([[0.0]*1024]*(self.max_obj_num-len(textual_feature_list)))
            visual_feature_list.extend([[0.0]*2048]*(self.max_obj_num-len(visual_feature_list)))
            bbox_list.extend([[0.0]*4]*(self.max_obj_num-len(bbox_list)))
            obj_mask.extend([0]*(self.max_obj_num-len(obj_mask)))

        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.float),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'textual_feature': torch.tensor(textual_feature_list, dtype=torch.float),
            'visual_feature': torch.tensor(visual_feature_list, dtype=torch.float),
            'bbox': torch.tensor(bbox_list, dtype=torch.float),
            'obj_mask': torch.tensor(obj_mask, dtype=torch.long),
            'file': self.doc[idx]
        }

# %%
test_df = pd.read_csv('data/test_printed_dataframe.csv')

# %%
import copy
import pickle

with open('doc_info/printed_doc_info.pkl', 'rb') as f:
    printed_doc_info = pickle.load(f)

with open('doc_info/test_doc_info.pkl', 'rb') as f:
    test_doc_info = pickle.load(f)

combined_doc_info = copy.deepcopy(test_doc_info)
combined_doc_info.update(printed_doc_info)

# %%
tokenizer_path = 'unc-nlp/lxmert-base-uncased'
model_class = VTFT
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)

test_set = formnlu_taskb_test(test_df, combined_doc_info, tokenizer)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=False)

model_name = 'unc-nlp/lxmert-base-uncased'
model_path = f'models/{model_class.__name__}'

model = model_class(model_name).to(device)
load_model_path = f'{model_path}/epoch{best_epoch}'

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = model_class(model_name).to(device)
model.load_state_dict(torch.load(f'{load_model_path}.pth'))
model.to(device)
model.eval()
# Out:
# Some weights of the model checkpoint at unc-nlp/lxmert-base-uncased were not used when initializing LxmertModel: ['answer_head.logit_fc.0.bias', 'answer_head.logit_fc.0.weight', 'answer_head.logit_fc.2.bias', 'answer_head.logit_fc.2.weight', 'answer_head.logit_fc.3.bias', 'answer_head.logit_fc.3.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'obj_predict_head.decoder_dict.attr.bias', 'obj_predict_head.decoder_dict.attr.weight', 'obj_predict_head.decoder_dict.feat.bias', 'obj_predict_head.decoder_dict.feat.weight', 'obj_predict_head.decoder_dict.obj.bias', 'obj_predict_head.decoder_dict.obj.weight', 'obj_predict_head.transform.LayerNorm.bias', 'obj_predict_head.transform.LayerNorm.weight', 'obj_predict_head.transform.dense.bias', 'obj_predict_head.transform.dense.weight']
# - This IS expected if you are initializing LxmertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LxmertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at unc-nlp/lxmert-base-uncased were not used when initializing LxmertModel: ['answer_head.logit_fc.0.bias', 'answer_head.logit_fc.0.weight', 'answer_head.logit_fc.2.bias', 'answer_head.logit_fc.2.weight', 'answer_head.logit_fc.3.bias', 'answer_head.logit_fc.3.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'obj_predict_head.decoder_dict.attr.bias', 'obj_predict_head.decoder_dict.attr.weight', 'obj_predict_head.decoder_dict.feat.bias', 'obj_predict_head.decoder_dict.feat.weight', 'obj_predict_head.decoder_dict.obj.bias', 'obj_predict_head.decoder_dict.obj.weight', 'obj_predict_head.transform.LayerNorm.bias', 'obj_predict_head.transform.LayerNorm.weight', 'obj_predict_head.transform.dense.bias', 'obj_predict_head.transform.dense.weight']
# - This IS expected if you are initializing LxmertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LxmertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# VTFT(
#   (text_proj): Linear(in_features=1024, out_features=2048, bias=True)
#   (lxmert): LxmertModel(
#     (embeddings): LxmertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768, padding_idx=0)
#       (token_type_embeddings): Embedding(2, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LxmertEncoder(
#       (visn_fc): LxmertVisualFeatureEncoder(
#         (visn_fc): Linear(in_features=2048, out_features=768, bias=True)
#         (visn_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (box_fc): Linear(in_features=4, out_features=768, bias=True)
#         (box_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (layer): ModuleList(
#         (0-8): 9 x LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (x_layers): ModuleList(
#         (0-4): 5 x LxmertXLayer(
#           (visual_attention): LxmertCrossAttentionLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (r_layers): ModuleList(
#         (0-4): 5 x LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttentionOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LxmertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (fc): Linear(in_features=1536, out_features=2048, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=2048, out_features=1, bias=True)
# )

# %%
def inference(model, data_loader, doc_info):
    model.eval()
    predictions = []

    with torch.no_grad():
        for _, data in tqdm(enumerate(data_loader, 0)):
            ids = data['ids'].to(device)
            mask = data['mask'].to(device)
            token_type_ids = data['token_type_ids'].to(device)
            textual_feature = data['textual_feature'].to(device)
            visual_feature = data['visual_feature'].to(device)
            bbox = data['bbox'].to(device)
            obj_mask = data['obj_mask'].to(device)
            file_names = data['file']

            logits = model(input_ids=ids, attention_mask=mask, token_type_ids=token_type_ids, textual_feature=textual_feature,
                       visual_feats=visual_feature, obj_attention_mask=obj_mask, visual_pos=bbox).view(ids.shape[0],-1)
            probs = F.sigmoid(logits)

            for i, file_name in enumerate(file_names):
                doc_id = file_name.replace('.png', '')
                page = doc_info[doc_id]
                valid_probs = probs[i][:len(page['objects'])]

                predicted_id = torch.argmax(valid_probs).item()

                global_id = list(page['objects'].values())[predicted_id]['global_id']
                predictions.append(global_id)

    return predictions

# %%
predictions = inference(model, test_loader, combined_doc_info)
# Out:
# 73it [00:47,  1.55it/s]

# %%
output_path = f'./results/{model_class.__name__}'

os.makedirs(output_path, exist_ok=True)

file_name = output_path + f'/submission.csv'

test_df = test_df.drop(columns=['Source', 'file', 'key_fix_text'])
test_df['Label'] = predictions
test_df.to_csv(file_name, index=False)
print(f"Predictions saved to {file_name}")
